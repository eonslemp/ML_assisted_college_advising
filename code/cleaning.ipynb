# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# %%
columns = ['BYHOMLIT','BYRISKFC','BYOCC30',
          'BYTXMSTD','BYTXRSTD','BYMATHSE','BYENGLSE','BYWRTNGA','BYHMWRK',
          'BYTVVIGM','BYWRKHRS', 'BYNSPORT','BYXTRACU','F1STEXP','F1OCC30',
           'F1TXMSTD','F1HIMATH','F1PSEPLN','F1RGPP2','F1XTRACU','F1WRKHRS',
           'F1TVVIGM','F1MATHSE','F1RHTUNP','F3EVRATT','F3PS1LVL','F3PSLCRED',
           'F3PS2BA','F3ATTAINMENT','F3F1EDEXPFF','F3ERN2011']

# %% [markdown]
# These are the columns from the initial study I am keeping for this analysis.

# %%
df = pd.read_csv('../els_02_12_byf3pststu_v1_0.csv',
                 usecols = columns)

# %%
df.head(1)
# Out:
#    BYHOMLIT  BYRISKFC  BYOCC30  BYTXMSTD  BYTXRSTD  BYMATHSE  BYENGLSE  \
# 0         0         2       -1     52.11     59.53    -1.118    -0.633
#
#    BYWRTNGA  BYNSPORT  BYXTRACU  BYHMWRK  BYTVVIGM  BYWRKHRS  F1STEXP  \
# 0     1.191         0         1        7        99         6        3
#
#    F1OCC30  F1TXMSTD  F1HIMATH  F1PSEPLN  F1XTRACU  F1WRKHRS  F1TVVIGM  \
# 0        7      49.6         5         2         1         6         3
#
#    F1MATHSE  F1RHTUNP  F1RGPP2  F3EVRATT  F3PS1LVL  F3PSLCRED  F3PS2BA  \
# 0    -0.258        31        2         1         2          0       -3
#
#    F3ATTAINMENT  F3F1EDEXPFF  F3ERN2011
# 0             3            1       4000

# %% [markdown]
# This function renames columns to more descriptive names.

# %%
def rename_cols(df):
    rename_list = ['literacy_home','risk_factors','aspired_occ_b','math_b',
                    'reading_b','math_conf_b','verbal_confidence','writing','sports','by_xcurr',
                    'homework','hedonics_b','hours_working_b','edu_confidence',
                    'aspired_occ_1','math_1','math_status_1','ps_step_1','f1_xcurr','hours_working_1',
                    'hedonics_1','math_conf_1','hs_ac_load','hs_gpa','any_ps','ps_level','graduated_Y',
                    'time_to_grad','edu_achievment','expected_edu','wages_yr']
    df.columns = rename_list
    return df

# %%
rename_cols(df)
# Out:
#        literacy_home  risk_factors  aspired_occ_b  math_b  reading_b  \
# 0                  0             2             -1   52.11      59.53
# 1                  3             0              9   57.65      56.70
# 2                  2            -9             10   66.44      64.46
# 3                  1            -4             10   44.68      48.69
# 4                  1             2             16   40.57      33.53
# ...              ...           ...            ...     ...        ...
# 16192              1            -4             15   32.98      44.62
# 16193              1             5             -1   35.91      33.78
# 16194              3             3             -1   36.85      40.56
# 16195              2             4             -1   48.87      43.51
# 16196              0            -9             11   62.37      61.26
#
#        math_conf_b  verbal_confidence  writing  sports  by_xcurr  homework  \
# 0           -1.118             -0.633    1.191       0         1         7
# 1            1.533              0.331    1.191       0         3         5
# 2           -0.154             -0.933    0.996       0         2        -9
# 3            1.030              1.146   -0.137       1         0        11
# 4            0.121              0.143   -0.435       0         0        10
# ...            ...                ...      ...     ...       ...       ...
# 16192       -0.118             -0.372   -4.000       1         0         4
# 16193       -0.381             -0.207   -4.000       1         1         6
# 16194       -0.355             -1.122   -4.000       0         0         4
# 16195        0.068             -0.118   -4.000       0         1        25
# 16196        1.772             -0.933   -0.898       4         2        -9
#
#        hedonics_b  hours_working_b  edu_confidence  aspired_occ_1  math_1  \
# 0              99                6               3              7   49.60
# 1               4                0               8             10   60.64
# 2               1                0               6             -9   64.26
# 3              99                0               6             -1   45.59
# 4               4                3               7             16   38.79
# ...           ...              ...             ...            ...     ...
# 16192           2                7               6             -1   -8.00
# 16193           3                0               4             -9   34.57
# 16194          99                0               8             -1   -8.00
# 16195           5                4               5             -1   -8.00
# 16196           1                0              -4             -4   -8.00
#
#        math_status_1  ps_step_1  f1_xcurr  hours_working_1  hedonics_1  \
# 0                  5          2         1                6           3
# 1                  6          5         2                1           2
# 2                  6          5         2                0           2
# 3                  4          4         1                5          99
# 4                  5          5         0                6           1
# ...              ...        ...       ...              ...         ...
# 16192              6          5         2                7          99
# 16193              5          3         3                8           5
# 16194              6         -8        -8                8           1
# 16195              5          6         1                5           4
# 16196             -4         -4        -4               -4          -4
#
#        math_conf_1  hs_ac_load  hs_gpa  any_ps  ps_level  graduated_Y  \
# 0           -0.258          31       2       1         2            0
# 1            0.528          31       4       1         1            1
# 2           -0.215          30       4       1         1            1
# 3            0.238          32       4       1         2            0
# 4            1.024          32       4       1         2            0
# ...            ...         ...     ...     ...       ...          ...
# 16192       -8.000          24       2      -4        -4           -4
# 16193        0.577          16       3       0        -3           -3
# 16194       -8.000           6       2      -4        -4           -4
# 16195       -8.000          23       5       1         2            0
# 16196       -4.000          12       1       1         2            1
#
#        time_to_grad  edu_achievment  expected_edu  wages_yr
# 0                -3               3             1      4000
# 1                44              10             2      3000
# 2                45               6             2     37000
# 3                -3               4             3      1500
# 4                -3               4             3     48000
# ...             ...             ...           ...       ...
# 16192            -4              -4            -9        -4
# 16193            -3               1             3      7000
# 16194            -4              -4            -9        -4
# 16195            -3               4             5     20000
# 16196            -3               4            -9     36000
#
# [16197 rows x 31 columns]

# %% [markdown]
# Subsetting dataframe for and initial exploration to justify why this analysis will neglect a portion of the data.

# %%
lost = df[df.ps_level < 0]
post = df[(df.math_1 > 0)
        &(df.math_b > 0)
        &(df.reading_b > 0)
        & (df.ps_level >= 0)
        &(df.graduated_Y >=0)]

# %%
post.shape
# Out:
# (9901, 31)

# %% [markdown]
# Less than zero responses are null values.  Significant amounts of data is null in the'lost' subset.

# %%
print(lost[lost.wages_yr < 0].shape)
# Out:
# (2947, 31)

# %%
print(f'base year reading score mean of whole dataset:  {round(df.reading_b.mean())}')
print(f'base year math score mean of whole dateset:  {round(df.math_b.mean())} \n')

print(f'standard deviation of base year reading score for whole dataset:  {round(df.reading_b.std())}')
print(f'standard deviation of base year math score for whole dataset:  {round(df.math_b.std())} \n')

print(f'base year reading score mean of lost:  {round(lost.reading_b.mean())}')
print(f'base year math score mean of lost:  {round(lost.math_b.mean())} \n')

print(f'base year reading score mean of ps:  {round(post.reading_b.mean())}')
print(f'base year math score mean of ps:  {round(post.math_b.mean())}\n')


print(f'null wages of lost: {lost[lost.wages_yr < 0].shape}')
print(f'mean wages of lost: {round(lost.wages_yr.mean())}\n')

print(f'null wages of ps: {post[post.wages_yr < 0].shape}')
print(f'mean wages of ps:  {round(post.wages_yr.mean())}')
# Out:
# base year reading score mean of whole dataset:  49.0
# base year math score mean of whole dateset:  50.0
#
# standard deviation of base year reading score for whole dataset:  13.0
# standard deviation of base year math score for whole dataset:  13.0
#
# base year reading score mean of lost:  44.0
# base year math score mean of lost:  44.0
#
# base year reading score mean of ps:  53.0
# base year math score mean of ps:  53.0
#
# null wages of lost: (2947, 31)
# mean wages of lost: 7933.0
#
# null wages of ps: (0, 31)
# mean wages of ps:  27801.0

# %% [markdown]
# There is significant null value in the 'lost'  subset.  Also what is probably not a coincidence these indiviudals did not pursue any form of post seconadary training as defined by the study.  As the analysis goes further we focus on this subset that pursued post secondary training in the form of 4 yr college, community college, or trade school.

# %% [markdown]
# ## post secondary

# %%
df = pd.read_csv('../els_02_12_byf3pststu_v1_0.csv',
                 usecols = columns,
                 na_values = [-9,-8,-4, -7,-3, 97, 98, 99])

# %% [markdown]
# 'na_values'  are defined in the study above and I read them in as null values.  Below the columns are renamed as above.

# %%
rename_cols(df)
# Out:
#        literacy_home  risk_factors  aspired_occ_b  math_b  reading_b  \
# 0                0.0           2.0           -1.0   52.11      59.53
# 1                3.0           0.0            9.0   57.65      56.70
# 2                2.0           NaN           10.0   66.44      64.46
# 3                1.0           NaN           10.0   44.68      48.69
# 4                1.0           2.0           16.0   40.57      33.53
# ...              ...           ...            ...     ...        ...
# 16192            1.0           NaN           15.0   32.98      44.62
# 16193            1.0           5.0           -1.0   35.91      33.78
# 16194            3.0           3.0           -1.0   36.85      40.56
# 16195            2.0           4.0           -1.0   48.87      43.51
# 16196            0.0           NaN           11.0   62.37      61.26
#
#        math_conf_b  verbal_confidence  writing  sports  by_xcurr  homework  \
# 0           -1.118             -0.633    1.191     0.0       1.0       7.0
# 1            1.533              0.331    1.191     0.0       3.0       5.0
# 2           -0.154             -0.933    0.996     0.0       2.0       NaN
# 3            1.030              1.146   -0.137     1.0       0.0      11.0
# 4            0.121              0.143   -0.435     0.0       0.0      10.0
# ...            ...                ...      ...     ...       ...       ...
# 16192       -0.118             -0.372      NaN     1.0       0.0       4.0
# 16193       -0.381             -0.207      NaN     1.0       1.0       6.0
# 16194       -0.355             -1.122      NaN     0.0       0.0       4.0
# 16195        0.068             -0.118      NaN     0.0       1.0      25.0
# 16196        1.772             -0.933   -0.898     4.0       2.0       NaN
#
#        hedonics_b  hours_working_b  edu_confidence  aspired_occ_1  math_1  \
# 0             NaN              6.0             3.0            7.0   49.60
# 1             4.0              0.0             8.0           10.0   60.64
# 2             1.0              0.0             6.0            NaN   64.26
# 3             NaN              0.0             6.0           -1.0   45.59
# 4             4.0              3.0             7.0           16.0   38.79
# ...           ...              ...             ...            ...     ...
# 16192         2.0              7.0             6.0           -1.0     NaN
# 16193         3.0              0.0             4.0            NaN   34.57
# 16194         NaN              0.0             8.0           -1.0     NaN
# 16195         5.0              4.0             5.0           -1.0     NaN
# 16196         1.0              0.0             NaN            NaN     NaN
#
#        math_status_1  ps_step_1  f1_xcurr  hours_working_1  hedonics_1  \
# 0                5.0        2.0       1.0              6.0         3.0
# 1                6.0        5.0       2.0              1.0         2.0
# 2                6.0        5.0       2.0              0.0         2.0
# 3                4.0        4.0       1.0              5.0         NaN
# 4                5.0        5.0       0.0              6.0         1.0
# ...              ...        ...       ...              ...         ...
# 16192            6.0        5.0       2.0              7.0         NaN
# 16193            5.0        3.0       3.0              8.0         5.0
# 16194            6.0        NaN       NaN              8.0         1.0
# 16195            5.0        6.0       1.0              5.0         4.0
# 16196            NaN        NaN       NaN              NaN         NaN
#
#        math_conf_1  hs_ac_load  hs_gpa  any_ps  ps_level  graduated_Y  \
# 0           -0.258        31.0     2.0     1.0       2.0          0.0
# 1            0.528        31.0     4.0     1.0       1.0          1.0
# 2           -0.215        30.0     4.0     1.0       1.0          1.0
# 3            0.238        32.0     4.0     1.0       2.0          0.0
# 4            1.024        32.0     4.0     1.0       2.0          0.0
# ...            ...         ...     ...     ...       ...          ...
# 16192          NaN        24.0     2.0     NaN       NaN          NaN
# 16193        0.577        16.0     3.0     0.0       NaN          NaN
# 16194          NaN         6.0     2.0     NaN       NaN          NaN
# 16195          NaN        23.0     5.0     1.0       2.0          0.0
# 16196          NaN        12.0     1.0     1.0       2.0          1.0
#
#        time_to_grad  edu_achievment  expected_edu  wages_yr
# 0               NaN             3.0           1.0    4000.0
# 1              44.0            10.0           2.0    3000.0
# 2              45.0             6.0           2.0   37000.0
# 3               NaN             4.0           3.0    1500.0
# 4               NaN             4.0           3.0   48000.0
# ...             ...             ...           ...       ...
# 16192           NaN             NaN           NaN       NaN
# 16193           NaN             1.0           3.0    7000.0
# 16194           NaN             NaN           NaN       NaN
# 16195           NaN             4.0           5.0   20000.0
# 16196           NaN             4.0           NaN   36000.0
#
# [16197 rows x 31 columns]

# %% [markdown]
# Subsetting the data to observations values critical to the analysis are present.

# %%
ps = df[(df.math_1 > 0) 
        & (df.math_b > 0)
        & (df.reading_b > 0)
        &  (df.ps_level >= 0)
        & (df.graduated_Y >=0)]

# %% [markdown]
# From these manipulations I have lost about 7000 observations from the original approx. 16000.

# %%
ps.shape
# Out:
# (9901, 31)

# %% [markdown]
# adjusting NaN value in 'hs_gpa' separately because some of its NaN value are positive integers above '6'.  These value are not NaN in other features, so it must be handled individually.

# %%
ps.hs_gpa.value_counts()
# Out:
# 5.0    2473
# 6.0    2286
# 4.0    2113
# 3.0    1532
# 2.0     671
# 1.0     161
# 0.0      33
# Name: hs_gpa, dtype: int64

# %%
ps.loc[ps.hs_gpa > 6] = np.NaN
# Out:
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ps.hs_gpa.isnull().sum()
# Out:
# 632

# %% [markdown]
# Adding features to enhance interpretability and hopefully enhace meaning and allow for future dimensinoality reduction.

# %%
def add_cool_features(df):
    df.loc[:,'effort'] = (df.homework*df.hs_ac_load)
    df.loc[:,'testing'] = df.math_b+df.reading_b+df.math_1
    df.loc[:,'v_facility'] = df.reading_b*(df.literacy_home + 1)
    df.loc[:,'m_facility'] = df.math_status_1*df.math_1
    df.loc[:,'academic_p'] = (df.effort)*df.hs_gpa
    df.loc[:,'iq_by_concientiousness'] = (df.v_facility+df.m_facility)*(df.homework+df.hs_ac_load)
    df.loc[:,'delinquency'] = df.risk_factors*(df.hedonics_b + df.hedonics_1)
    #df['effort'] = (df.homework+df.hs_ac_load)
    df.loc[:,'wages_cont'] = df.testing*df.wages_yr
    return df

# %%
add_cool_features(ps)
# Out:
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#        literacy_home  risk_factors  aspired_occ_b  math_b  reading_b  \
# 0                0.0           2.0           -1.0   52.11      59.53
# 1                3.0           0.0            9.0   57.65      56.70
# 2                2.0           NaN           10.0   66.44      64.46
# 3                1.0           NaN           10.0   44.68      48.69
# 4                1.0           2.0           16.0   40.57      33.53
# ...              ...           ...            ...     ...        ...
# 16169            3.0           NaN           -1.0   48.94      59.41
# 16172            1.0           NaN           -1.0   74.90      64.83
# 16174            3.0           1.0           -1.0   54.31      59.29
# 16175            2.0           0.0            7.0   69.18      69.76
# 16186            1.0           1.0            NaN   57.99      56.70
#
#        math_conf_b  verbal_confidence  writing  sports  by_xcurr  homework  \
# 0           -1.118             -0.633    1.191     0.0       1.0       7.0
# 1            1.533              0.331    1.191     0.0       3.0       5.0
# 2           -0.154             -0.933    0.996     0.0       2.0       NaN
# 3            1.030              1.146   -0.137     1.0       0.0      11.0
# 4            0.121              0.143   -0.435     0.0       0.0      10.0
# ...            ...                ...      ...     ...       ...       ...
# 16169          NaN                NaN    0.052     2.0       0.0      19.0
# 16172          NaN                NaN    0.052     1.0       1.0       9.0
# 16174        0.571                NaN      NaN     0.0       0.0      19.0
# 16175        0.808              0.404    0.618     2.0       0.0      26.0
# 16186          NaN                NaN      NaN     NaN       0.0       4.0
#
#        hedonics_b  hours_working_b  edu_confidence  aspired_occ_1  math_1  \
# 0             NaN              6.0             3.0            7.0   49.60
# 1             4.0              0.0             8.0           10.0   60.64
# 2             1.0              0.0             6.0            NaN   64.26
# 3             NaN              0.0             6.0           -1.0   45.59
# 4             4.0              3.0             7.0           16.0   38.79
# ...           ...              ...             ...            ...     ...
# 16169         4.0              0.0             6.0           -1.0   52.52
# 16172         0.0              0.0             6.0            9.0   74.48
# 16174         0.0              0.0             6.0            9.0   50.56
# 16175         2.0              0.0             7.0            7.0   69.14
# 16186         NaN              NaN             4.0           10.0   55.60
#
#        math_status_1  ps_step_1  f1_xcurr  hours_working_1  hedonics_1  \
# 0                5.0        2.0       1.0              6.0         3.0
# 1                6.0        5.0       2.0              1.0         2.0
# 2                6.0        5.0       2.0              0.0         2.0
# 3                4.0        4.0       1.0              5.0         NaN
# 4                5.0        5.0       0.0              6.0         1.0
# ...              ...        ...       ...              ...         ...
# 16169            6.0        5.0       2.0              5.0         3.0
# 16172            6.0        5.0       4.0              0.0         0.0
# 16174            6.0        5.0       1.0              8.0         5.0
# 16175            6.0        5.0       4.0              9.0         2.0
# 16186            5.0        4.0       0.0              1.0         8.0
#
#        math_conf_1  hs_ac_load  hs_gpa  any_ps  ps_level  graduated_Y  \
# 0           -0.258        31.0     2.0     1.0       2.0          0.0
# 1            0.528        31.0     4.0     1.0       1.0          1.0
# 2           -0.215        30.0     4.0     1.0       1.0          1.0
# 3            0.238        32.0     4.0     1.0       2.0          0.0
# 4            1.024        32.0     4.0     1.0       2.0          0.0
# ...            ...         ...     ...     ...       ...          ...
# 16169        0.264        33.0     4.0     1.0       1.0          1.0
# 16172        0.528        28.0     6.0     1.0       1.0          1.0
# 16174       -0.755        29.0     4.0     1.0       1.0          1.0
# 16175        1.811        29.0     5.0     1.0       1.0          0.0
# 16186          NaN        28.0     2.0     1.0       2.0          0.0
#
#        time_to_grad  edu_achievment  expected_edu  wages_yr  effort  testing  \
# 0               NaN             3.0           1.0    4000.0   217.0   161.24
# 1              44.0            10.0           2.0    3000.0   155.0   174.99
# 2              45.0             6.0           2.0   37000.0     NaN   195.16
# 3               NaN             4.0           3.0    1500.0   352.0   138.96
# 4               NaN             4.0           3.0   48000.0   320.0   112.89
# ...             ...             ...           ...       ...     ...      ...
# 16169          45.0             6.0           2.0   40000.0   627.0   160.87
# 16172          59.0             6.0           2.0   90000.0   252.0   214.21
# 16174          88.0             6.0           2.0    8000.0   551.0   164.16
# 16175           NaN             3.0           3.0   15000.0   754.0   208.08
# 16186           NaN             5.0           5.0   14000.0   112.0   170.29
#
#        v_facility  m_facility  academic_p  iq_by_concientiousness  \
# 0           59.53      248.00       434.0                11686.14
# 1          226.80      363.84       620.0                21263.04
# 2          193.38      385.56         NaN                     NaN
# 3           97.38      182.36      1408.0                12028.82
# 4           67.06      193.95      1280.0                10962.42
# ...           ...         ...         ...                     ...
# 16169      237.64      315.12      2508.0                28743.52
# 16172      129.66      446.88      1512.0                21331.98
# 16174      237.16      303.36      2204.0                25944.96
# 16175      209.28      414.84      3770.0                34326.60
# 16186      113.40      278.00       224.0                12524.80
#
#        delinquency  wages_cont
# 0              NaN    644960.0
# 1              0.0    524970.0
# 2              NaN   7220920.0
# 3              NaN    208440.0
# 4             10.0   5418720.0
# ...            ...         ...
# 16169          NaN   6434800.0
# 16172          NaN  19278900.0
# 16174          5.0   1313280.0
# 16175          0.0   3121200.0
# 16186          NaN   2384060.0
#
# [9901 rows x 39 columns]

# %% [markdown]
# The following csv is saved here to have a pre-imputation subsetted dataset available.

# %%
ps.to_csv('post_secondary.csv')

# %% [markdown]
# Dropping these features because they may leak data in modelling.  I have kept them because they may be useful in a future iteration of the project.   This set will also be useful in some of the exploratory analysis.

# %%
drop_list = ['any_ps','ps_step_1', 'wages_yr',
            'time_to_grad','edu_achievment','expected_edu']
def drop_stuff(df, l):
    for i in l:
        df.drop(i, axis = 1, inplace = True)
    return df

# %%
ps_dropped = drop_stuff(ps,drop_list)
# Out:
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# Function to split and into train/test and rejoin features and target for convenience.

# %%
def x_y_split(df):    
    #splits target from data
    x = df.iloc[:,(df.columns!='graduated_Y')]
    y = df.graduated_Y
    
    #creates test train split
    X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=4, test_size=0.2)
    
    #rejoins target to dataset 
    test = pd.concat([X_test, y_test], axis = 1)
    train = pd.concat([X_train, y_train], axis = 1)
    
    return train, test

# %%
college_train, college_test = x_y_split(ps_dropped)

# %% [markdown]
# Inspecting sizes of the train and test sets.

# %%
print("Training set shape: ", college_train.shape)
print("Test set shape: ", college_test.shape)
# Out:
# Training set shape:  (7920, 33)
# Test set shape:  (1981, 33)

# %% [markdown]
# Creating a file of train set before a series of preprocessing steps.

# %%
college_train.to_csv('college_train.csv')

# %%
def KNNimpute_DF(df):
    #filling in missing values with knn imputer
    imputer_knn = KNNImputer(n_neighbors = 10)
    imputer_knn.fit(df)

    x = imputer_knn.transform(df)
    
    #casting the numpy array to dataframe
    df = pd.DataFrame(x)
    return df

# %% [markdown]
# Imputation of train set.

# %%
imputed_coll_train = KNNimpute_DF(college_train)

# %%
def rename_cols_x(df):
    rename_list = college_train.columns
    df.columns = rename_list
    return df

# %% [markdown]
# Renaming columns.

# %%
train_college_imp = rename_cols_x(imputed_coll_train)

# %%
train_college_imp.head()
# Out:
#    literacy_home  risk_factors  aspired_occ_b  math_b  reading_b  math_conf_b  \
# 0            3.0           1.0           10.0   64.65      65.70       0.7487
# 1            3.0           0.4            9.0   63.74      64.71       0.3600
# 2            2.0           0.0           -1.0   40.50      46.23      -0.1830
# 3            2.0           1.0           10.0   59.68      51.03       0.7810
# 4            2.1           2.0           10.0   55.44      61.51       0.0139
#
#    verbal_confidence  writing  sports  by_xcurr  homework  hedonics_b  \
# 0             0.5229    0.052     0.0       1.0      10.0         1.0
# 1             0.6660    1.001     2.0       2.0      27.0         5.0
# 2             0.0780   -0.137     2.0       0.0      11.0         2.0
# 3            -1.1940    0.052     0.0       2.0       8.0         1.0
# 4             0.1298    0.052     0.0       1.0      13.0         2.0
#
#    hours_working_b  edu_confidence  aspired_occ_1  math_1  math_status_1  \
# 0              0.0             7.0           -1.0   65.65            6.0
# 1              0.0             7.0            9.0   60.59            5.0
# 2              0.0             6.0           -1.0   42.39            5.0
# 3              0.0             8.0           10.0   63.61            6.0
# 4              1.0             9.0           10.0   46.34            4.0
#
#    f1_xcurr  hours_working_1  hedonics_1  math_conf_1  hs_ac_load  hs_gpa  \
# 0       3.0              3.0         1.0       0.9824        32.0     6.0
# 1       3.0              1.0         1.0       0.7460        24.0     6.0
# 2       2.0              0.0         3.0       0.4950        24.0     4.0
# 3       3.0              4.0         2.0       0.4950        28.0     6.0
# 4       6.0              2.0         3.0      -1.2800        21.0     3.0
#
#    ps_level  effort  testing  v_facility  m_facility  academic_p  \
# 0       1.0   320.0   196.00      262.80      393.90      1920.0
# 1       1.0   648.0   189.04      258.84      302.95      3888.0
# 2       1.0   264.0   129.12      138.69      211.95      1056.0
# 3       1.0   224.0   174.32      153.09      381.66      1344.0
# 4       1.0   273.0   163.29      162.56      185.36       819.0
#
#    iq_by_concientiousness  delinquency  wages_cont  graduated_Y
# 0               27581.400          2.0         0.0          1.0
# 1               28651.290          3.1   8884880.0          1.0
# 2               12272.400          0.0     90384.0          1.0
# 3               19251.000          3.0  14817200.0          0.0
# 4               14068.011         10.0   4245540.0          0.0

# %%
def round_ordinals(x):
    ordinal_feature_list = ['literacy_home','risk_factors','aspired_occ_b','sports','by_xcurr',
                    'homework','hedonics_b','hours_working_b','edu_confidence',
                    'aspired_occ_1','math_status_1','f1_xcurr','hours_working_1',
                    'hedonics_1','hs_ac_load','hs_gpa','academic_p','graduated_Y']
    
    for k in ordinal_feature_list:
        x[k] = x.loc[:,k].apply(round)
    return x

# %% [markdown]
# during imputation ordinal and categorical values were made continious.  Reasserting the nature of these features by rounding.

# %%
round_ordinals(train_college_imp)
# Out:
#       literacy_home  risk_factors  aspired_occ_b  math_b  reading_b  \
# 0                 3             1             10   64.65      65.70
# 1                 3             0              9   63.74      64.71
# 2                 2             0             -1   40.50      46.23
# 3                 2             1             10   59.68      51.03
# 4                 2             2             10   55.44      61.51
# ...             ...           ...            ...     ...        ...
# 7915              0             2             10   48.97      39.82
# 7916              2             0              9   62.47      61.26
# 7917              1             1              2   60.06      55.22
# 7918              2             0             -1   50.40      48.81
# 7919              2             0              9   66.83      59.66
#
#       math_conf_b  verbal_confidence  writing  sports  by_xcurr  homework  \
# 0          0.7487             0.5229   0.0520       0         1        10
# 1          0.3600             0.6660   1.0010       2         2        27
# 2         -0.1830             0.0780  -0.1370       2         0        11
# 3          0.7810            -1.1940   0.0520       0         2         8
# 4          0.0139             0.1298   0.0520       0         1        13
# ...           ...                ...      ...     ...       ...       ...
# 7915      -1.8310            -1.9050  -0.8980       0         0         2
# 7916       1.3220             0.3310   0.3100       0         1         8
# 7917      -0.6300            -0.1260   0.1600       1         1         9
# 7918      -0.1540            -0.9330   0.3531       1         1        12
# 7919       1.7720             0.3310  -0.3380       2         2         8
#
#       hedonics_b  hours_working_b  edu_confidence  aspired_occ_1  math_1  \
# 0              1                0               7             -1   65.65
# 1              5                0               7              9   60.59
# 2              2                0               6             -1   42.39
# 3              1                0               8             10   63.61
# 4              2                1               9             10   46.34
# ...          ...              ...             ...            ...     ...
# 7915           3                0               6             -1   48.69
# 7916           8                0               7             11   56.32
# 7917           3                1               7              9   49.98
# 7918           4                0               6              9   44.59
# 7919           4                1               6              9   66.62
#
#       math_status_1  f1_xcurr  hours_working_1  hedonics_1  math_conf_1  \
# 0                 6         3                3           1       0.9824
# 1                 5         3                1           1       0.7460
# 2                 5         2                0           3       0.4950
# 3                 6         3                4           2       0.4950
# 4                 4         6                2           3      -1.2800
# ...             ...       ...              ...         ...          ...
# 7915              4         1                5           1      -0.8084
# 7916              5         3                1           2       1.0240
# 7917              5         2                2           5      -0.5100
# 7918              6         5                1           3       0.0014
# 7919              6         4                0           4       1.5640
#
#       hs_ac_load  hs_gpa  ps_level  effort  testing  v_facility  m_facility  \
# 0             32       6       1.0   320.0   196.00      262.80      393.90
# 1             24       6       1.0   648.0   189.04      258.84      302.95
# 2             24       4       1.0   264.0   129.12      138.69      211.95
# 3             28       6       1.0   224.0   174.32      153.09      381.66
# 4             21       3       1.0   273.0   163.29      162.56      185.36
# ...          ...     ...       ...     ...      ...         ...         ...
# 7915          24       4       2.0    48.0   137.48       39.82      194.76
# 7916          15       4       1.0   120.0   180.05      183.78      281.60
# 7917          27       5       1.0   243.0   165.26      110.44      249.90
# 7918          28       5       1.0   336.0   143.80      146.43      267.54
# 7919          26       6       1.0   174.9   193.11      178.98      399.72
#
#       academic_p  iq_by_concientiousness  delinquency  wages_cont  graduated_Y
# 0           1920               27581.400          2.0         0.0            1
# 1           3888               28651.290          3.1   8884880.0            1
# 2           1056               12272.400          0.0     90384.0            1
# 3           1344               19251.000          3.0  14817200.0            0
# 4            819               14068.011         10.0   4245540.0            0
# ...          ...                     ...          ...         ...          ...
# 7915         192                6099.080         12.5     13748.0            1
# 7916         480               10703.740          2.6   5221450.0            0
# 7917        1215               12972.240          6.5   8758780.0            0
# 7918        1680               16558.800          5.2   3595000.0            1
# 7919         803               13920.479          0.0   1158660.0            0
#
# [7920 rows x 33 columns]

# %% [markdown]
# Creating dummy variable for these two categorical features.

# %%
train_college_imp = pd.get_dummies(train_college_imp,
            columns = ['aspired_occ_b','aspired_occ_1'])

# %% [markdown]
# Saving a copy of train set after these manipulation.

# %%
train_college_imp.to_csv('train_college_imp.csv')

# %% [markdown]
# Doing the process of saving, imputing, renaming, and rounding to the test set.

# %%
college_test.to_csv('college_test.csv')

imputed_coll_test = KNNimpute_DF(college_test)

test_college_imp = rename_cols_x(imputed_coll_test)

round_ordinals(test_college_imp)
# Out:
#       literacy_home  risk_factors  aspired_occ_b  math_b  reading_b  \
# 0                 3             1             10   61.29      66.44
# 1                 2             1             10   52.98      56.70
# 2                 2             1              9   41.14      41.79
# 3                 3             0             -1   69.05      67.17
# 4                 3             0             10   65.82      65.33
# ...             ...           ...            ...     ...        ...
# 1976              2             0             10   64.42      61.01
# 1977              1             0             -1   57.94      46.72
# 1978              2             0             11   71.53      58.79
# 1979              1             1             10   48.41      46.23
# 1980              3             1              5   57.65      55.10
#
#       math_conf_b  verbal_confidence  writing  sports  by_xcurr  homework  \
# 0          1.7720             1.5960    1.951       2         3         2
# 1         -1.1060             0.3310    1.001       1         1        13
# 2          0.3330            -1.1940   -0.703       0         0         2
# 3          1.7720             1.5960    1.951       1         1        10
# 4          0.5710             0.8930    0.539       1         0         2
# ...           ...                ...      ...     ...       ...       ...
# 1976      -0.1708             0.0458    0.812       4         7        12
# 1977      -0.6300            -0.7450    0.515       2         0        15
# 1978       1.5330            -0.2300    0.733       0         1        34
# 1979       0.1748            -0.3639    0.247       2         5         8
# 1980      -0.2475            -0.1141    0.539       1         0        12
#
#       hedonics_b  hours_working_b  edu_confidence  aspired_occ_1  math_1  \
# 0              1                0               8             10   63.02
# 1              3                0               6              9   51.00
# 2              4                0               3             -1   43.86
# 3              3                0               6             -1   71.56
# 4              3                2               8             10   65.92
# ...          ...              ...             ...            ...     ...
# 1976           0                0               7             -1   63.07
# 1977           4                0               6              9   58.57
# 1978           3                1               7             11   70.78
# 1979           4                4               8             12   51.03
# 1980           3                1               6             15   58.44
#
#       math_status_1  f1_xcurr  hours_working_1  hedonics_1  math_conf_1  \
# 0                 6         5                0           1       1.3020
# 1                 5         6                8           2      -0.2590
# 2                 5         1                0           2      -0.3042
# 3                 6         4                0           2       1.8110
# 4                 6         3                1           3      -0.5100
# ...             ...       ...              ...         ...          ...
# 1976              6         6                6           1       1.3030
# 1977              6         3                5           3       0.5280
# 1978              6         2                4           1       0.8791
# 1979              5         3                4           1      -0.0130
# 1980              6         1                3           1      -0.7550
#
#       hs_ac_load  hs_gpa  ps_level  effort  testing  v_facility  m_facility  \
# 0             26       6       1.0    52.0   190.75     265.760      378.12
# 1             28       5       1.0   364.0   160.68     170.100      255.00
# 2             21       4       1.0    42.0   126.79     125.370      219.30
# 3             26       6       1.0   260.0   207.78     268.680      429.36
# 4             26       5       1.0    52.0   197.07     261.320      395.52
# ...          ...     ...       ...     ...      ...         ...         ...
# 1976          28       6       1.0   336.0   188.50     161.835      378.42
# 1977          25       4       1.0   375.0   163.23      93.440      351.42
# 1978          27       5       1.0   445.7   201.10     176.370      424.68
# 1979          31       4       1.0   178.3   145.67      92.460      255.15
# 1980          30       5       1.0   360.0   171.19     220.400      350.64
#
#       academic_p  iq_by_concientiousness  delinquency  wages_cont  graduated_Y
# 0            312               18028.640          4.7   2670500.0            1
# 1           1820               17429.100          5.0         0.0            0
# 2            168                7927.410          6.0         0.0            0
# 3           1560               25129.440          0.0   4155600.0            1
# 4            260               18391.520          0.0   2364840.0            0
# ...          ...                     ...          ...         ...          ...
# 1976        2016               14170.718          0.0   1790750.0            0
# 1977        1500               17794.400          0.0   8161500.0            1
# 1978        2492               25206.352          0.0  15082500.0            1
# 1979         602               11150.495          5.0         0.0            0
# 1980        1800               23983.680          4.2   4793320.0            1
#
# [1981 rows x 33 columns]

# %% [markdown]
# Generating dummies from categoricals in the test set.

# %%
test_college_imp = pd.get_dummies(test_college_imp, 
            columns = ['aspired_occ_b','aspired_occ_1'])

# %% [markdown]
# Verifying the two sets have the same number of features.

# %%
print(train_college_imp.shape)
print(test_college_imp.shape)
# Out:
# (7920, 67)
# (1981, 67)

# %% [markdown]
# Saving the pre-processed test set.

# %%
test_college_imp.to_csv('test_college_imp.csv')

# %% [markdown]
# With these steps I have created the foundational datasets that will be used in the rest of the analysis.
